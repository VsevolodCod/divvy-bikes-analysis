# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from src.data.load_data import load_raw_data
from src.data.data_profiler import check_data
import polars as pl

df_January = load_raw_data(year=2023, month=1)
df_February = load_raw_data(year=2023, month=2)
df_March = load_raw_data(year=2023, month=3)
df_April = load_raw_data(year=2023, month=4)
df_May = load_raw_data(year=2023,month=5)
df_June  = load_raw_data(year=2023, month=6)
df_July = load_raw_data(year=2023, month=7)
df_August = load_raw_data(year=2023, month=8)
df_September  = load_raw_data(year=2023, month=9)
df_October  = load_raw_data(year=2023, month=10)
df_November = load_raw_data(year=2023, month=11)
df_December = load_raw_data(year=2023, month=12)

# %%
dfs = [
    df_January, df_February, df_March, df_April, df_May, df_June,
    df_July, df_August, df_September, df_October, df_November, df_December
]

df_full = pl.concat(dfs)

# %%
check_data(df_full)
# Out:
# ╔══════════════════════════════════════════════════════════╗
# ║               DATA PROFILING REPORT                      ║
# ╚══════════════════════════════════════════════════════════╝
#
#
# ============================================================
#   БАЗОВАЯ ИНФОРМАЦИЯ
# ============================================================
#
# Размер датасета:
#   Строк: 5,719,877
#   Колонок: 13
#   Размер в памяти: 746.75 MB
#
# Типы данных:
#   Datetime(time_unit='us', time_zone=None): 2 колонок
#   Float64: 4 колонок
#   String: 7 колонок
#
# Колонки:
#    1. ride_id                        (String)
#    2. rideable_type                  (String)
#    3. started_at                     (Datetime(time_unit='us', time_zone=None))
#    4. ended_at                       (Datetime(time_unit='us', time_zone=None))
#    5. start_station_name             (String)
#    6. start_station_id               (String)
#    7. end_station_name               (String)
#    8. end_station_id                 (String)
#    9. start_lat                      (Float64)
#   10. start_lng                      (Float64)
#   11. end_lat                        (Float64)
#   12. end_lng                        (Float64)
#   13. member_casual                  (String)
#
# ============================================================
#   АНАЛИЗ ПРОПУСКОВ
# ============================================================
#
# Общая статистика:
#   Всего пропусков: 3,624,089
#   Доля пропусков: 4.87%
#   Строк с пропусками: 1,388,170 (24.27%)
#
# Пропуски по колонкам:
#   • start_station_name            :  875,716 (15.31%)
#   • start_station_id              :  875,848 (15.31%)
#   • end_station_name              :  929,202 (16.25%)
#   • end_station_id                :  929,343 (16.25%)
#   • end_lat                       :    6,990 ( 0.12%)
#   • end_lng                       :    6,990 ( 0.12%)
#
# ============================================================
#   ПРОВЕРКА ДУБЛИКАТОВ
# ============================================================
#
# Полные дубликаты:
#   Полных дубликатов не найдено
#
# Уникальность:
#   Уникальных строк: 5,719,877
#   Доля уникальных: 100.00%
#
# ============================================================
#   ЧИСЛОВЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 4 числовых колонок
#
# shape: (9, 5)
# ┌────────────┬────────────┬────────────┬────────────┬────────────┐
# │ statistic  ┆ start_lat  ┆ start_lng  ┆ end_lat    ┆ end_lng    │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ str        ┆ f64        ┆ f64        ┆ f64        ┆ f64        │
# ╞════════════╪════════════╪════════════╪════════════╪════════════╡
# │ count      ┆ 5.719877e6 ┆ 5.719877e6 ┆ 5.712887e6 ┆ 5.712887e6 │
# │ null_count ┆ 0.0        ┆ 0.0        ┆ 6990.0     ┆ 6990.0     │
# │ mean       ┆ 41.902885  ┆ -87.647036 ┆ 41.903221  ┆ -87.647203 │
# │ std        ┆ 0.045056   ┆ 0.027334   ┆ 0.054444   ┆ 0.069196   │
# │ min        ┆ 41.63      ┆ -87.94     ┆ 0.0        ┆ -88.16     │
# │ 25%        ┆ 41.880958  ┆ -87.66     ┆ 41.881032  ┆ -87.660274 │
# │ 50%        ┆ 41.899019  ┆ -87.644031 ┆ 41.9       ┆ -87.644098 │
# │ 75%        ┆ 41.93      ┆ -87.629912 ┆ 41.93      ┆ -87.63     │
# │ max        ┆ 42.07      ┆ -87.46     ┆ 42.18      ┆ 0.0        │
# └────────────┴────────────┴────────────┴────────────┴────────────┘
#
# ============================================================
#   КАТЕГОРИАЛЬНЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 7 категориальных колонок
#
# ▸ ride_id
#   Уникальных значений: 5,719,877
#   Пропусков: 0
#   Топ-5 значений:
#     - E07112565CB7F240                        :        1 ( 0.00%)
#     - 7AA972F320E81F0A                        :        1 ( 0.00%)
#     - ECA5E391672E81B3                        :        1 ( 0.00%)
#     - EACC4CD27C57CA9B                        :        1 ( 0.00%)
#     - 8538BF897B0B8859                        :        1 ( 0.00%)
#
# ▸ rideable_type
#   Уникальных значений: 3
#   Пропусков: 0
#   Топ-5 значений:
#     - electric_bike                           : 2,945,579 (51.50%)
#     - classic_bike                            : 2,696,011 (47.13%)
#     - docked_bike                             :   78,287 ( 1.37%)
#
# ▸ start_station_name
#   Уникальных значений: 1,593
#   Пропусков: 875,716
#   Топ-5 значений:
#     - None                                    :  875,716 (15.31%)
#     - Streeter Dr & Grand Ave                 :   63,249 ( 1.11%)
#     - DuSable Lake Shore Dr & Monroe St       :   40,288 ( 0.70%)
#     - Michigan Ave & Oak St                   :   37,383 ( 0.65%)
#     - DuSable Lake Shore Dr & North Blvd      :   35,966 ( 0.63%)
#
# ▸ start_station_id
#   Уникальных значений: 1,517
#   Пропусков: 875,848
#   Топ-5 значений:
#     - None                                    :  875,848 (15.31%)
#     - 13022                                   :   63,249 ( 1.11%)
#     - 13300                                   :   40,288 ( 0.70%)
#     - 13042                                   :   37,383 ( 0.65%)
#     - LF-005                                  :   35,966 ( 0.63%)
#
# ▸ end_station_name
#   Уникальных значений: 1,598
#   Пропусков: 929,202
#   Топ-5 значений:
#     - None                                    :  929,202 (16.25%)
#     - Streeter Dr & Grand Ave                 :   64,197 ( 1.12%)
#     - DuSable Lake Shore Dr & North Blvd      :   39,301 ( 0.69%)
#     - DuSable Lake Shore Dr & Monroe St       :   38,022 ( 0.66%)
#     - Michigan Ave & Oak St                   :   37,997 ( 0.66%)
#
# ▸ end_station_id
#   Уникальных значений: 1,521
#   Пропусков: 929,343
#   Топ-5 значений:
#     - None                                    :  929,343 (16.25%)
#     - 13022                                   :   64,197 ( 1.12%)
#     - LF-005                                  :   39,301 ( 0.69%)
#     - 13300                                   :   38,022 ( 0.66%)
#     - 13042                                   :   37,997 ( 0.66%)
#
# ▸ member_casual
#   Уникальных значений: 2
#   Пропусков: 0
#   Топ-5 значений:
#     - member                                  : 3,660,698 (64.00%)
#     - casual                                  : 2,059,179 (36.00%)
#
#
# ============================================================
#   ВРЕМЕННЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 2 временных колонок
#
# ▸ started_at
#   Минимум: 2023-01-01 00:01:58
#   Максимум: 2023-12-31 23:59:38
#   Диапазон: 364 дней
#   Пропусков: 0
#
# ▸ ended_at
#   Минимум: 2023-01-01 00:02:41
#   Максимум: 2024-01-01 23:50:51
#   Диапазон: 365 дней
#   Пропусков: 0
#
#
# ============================================================
#   ПРИМЕРЫ ДАННЫХ
# ============================================================
#
# Первые 3 строк:
# shape: (3, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ride_id   ┆ rideable_ ┆ started_a ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat   ┆ end_lng   ┆ member_c │
# │ ---       ┆ type      ┆ t         ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ asual    │
# │ str       ┆ ---       ┆ ---       ┆ datetime[ ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆ str       ┆ datetime[ ┆ μs]       ┆   ┆           ┆           ┆           ┆ str      │
# │           ┆           ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ F96D5A74A ┆ electric_ ┆ 2023-01-2 ┆ 2023-01-2 ┆ … ┆ -87.64627 ┆ 41.93     ┆ -87.64    ┆ member   │
# │ 3E41399   ┆ bike      ┆ 1         ┆ 1         ┆   ┆ 8         ┆           ┆           ┆          │
# │           ┆           ┆ 20:05:42  ┆ 20:16:33  ┆   ┆           ┆           ┆           ┆          │
# │ 13CB7EB69 ┆ classic_b ┆ 2023-01-1 ┆ 2023-01-1 ┆ … ┆ -87.59474 ┆ 41.809835 ┆ -87.59938 ┆ member   │
# │ 8CEDB88   ┆ ike       ┆ 0         ┆ 0         ┆   ┆ 7         ┆           ┆ 3         ┆          │
# │           ┆           ┆ 15:37:36  ┆ 15:46:05  ┆   ┆           ┆           ┆           ┆          │
# │ BD88A2E67 ┆ electric_ ┆ 2023-01-0 ┆ 2023-01-0 ┆ … ┆ -87.69048 ┆ 42.039742 ┆ -87.69941 ┆ casual   │
# │ 0661CE5   ┆ bike      ┆ 2         ┆ 2         ┆   ┆ 3         ┆           ┆ 3         ┆          │
# │           ┆           ┆ 07:51:57  ┆ 08:05:11  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# Последние 3 строк:
# shape: (3, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ride_id   ┆ rideable_ ┆ started_a ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat   ┆ end_lng   ┆ member_c │
# │ ---       ┆ type      ┆ t         ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆