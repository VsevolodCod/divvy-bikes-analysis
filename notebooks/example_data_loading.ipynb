# %% [markdown]
# # Пример загрузки данных Divvy Bikes
#
# Этот notebook демонстрирует различные способы загрузки данных.

# %%
import sys
sys.path.append('..')

import polars as pl
from src.data.load_data import (
    load_trips, load_stations, load_daily_metrics,
    load_raw_data, DataLoader
)

# %% [markdown]
# ## 1. Быстрая загрузка готовых данных

# %%
# Загрузить все поездки (использует processed/trips_final.parquet если есть)
trips_df = load_trips()

print(f"Загружено поездок: {trips_df.shape[0]:,}")
print(f"Колонок: {trips_df.shape[1]}")
print(f"\nПервые строки:")
trips_df.head()
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Загрузить все поездки (использует processed/trips_final.parquet если есть)
# ----> 2 trips_df = load_trips()
#       4 print(f"Загружено поездок: {trips_df.shape[0]:,}")
#       5 print(f"Колонок: {trips_df.shape[1]}")
#
# File ~/Desktop/divvy-bikes-analysis/notebooks/../src/data/load_data.py:215, in load_trips(use_processed)
#     213 """Загрузить данные о поездках."""
#     214 loader = DataLoader()
# --> 215 return loader.load_all_trips(use_processed=use_processed)
#
# File ~/Desktop/divvy-bikes-analysis/notebooks/../src/data/load_data.py:186, in DataLoader.load_all_trips(self, use_processed)
#     184 else:
#     185     logger.info("Загрузка сырых данных о поездках")
# --> 186     return self.load_raw_trips_range(2013, 2025)
#
# File ~/Desktop/divvy-bikes-analysis/notebooks/../src/data/load_data.py:77, in DataLoader.load_raw_trips_range(self, start_year, end_year)
#      75 for year in range(start_year, end_year + 1):
#      76     try:
# ---> 77         df = self.load_raw_trips_year(year)
#      78         if df.height > 0:
#      79             df = df.with_columns(pl.lit(year).alias('year'))
#
# File ~/Desktop/divvy-bikes-analysis/notebooks/../src/data/load_data.py:59, in DataLoader.load_raw_trips_year(self, year)
#      56         logger.warning(f"Ошибка загрузки {file}: {e}")
#      58 if dfs:
# ---> 59     return pl.concat(dfs, how='diagonal')
#      60 else:
#      61     return pl.DataFrame()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/functions/eager.py:244, in concat(items, how, rechunk, parallel)
#     233     out = wrap_ldf(
#     234         plr.concat_lf(
#     235             [df.lazy() for df in elems],
#    (...)    240         )
#     241     ).collect(optimizations=QueryOptFlags._eager())
#     243 elif how == "diagonal":
# --> 244     out = wrap_df(plr.concat_df_diagonal(elems))
#     245 elif how == "diagonal_relaxed":
#     246     out = wrap_ldf(
#     247         plr.concat_lf_diagonal(
#     248             [df.lazy() for df in elems],
#    (...)    253         )
#     254     ).collect(optimizations=QueryOptFlags._eager())
#
# SchemaError: type Int64 is incompatible with expected type String

# %% [markdown]
# ## 2. Загрузка сырых данных за конкретный год

# %%
# Загрузить данные за 2024 год
trips_2024 = load_raw_data(year=2024)

print(f"Поездок за 2024: {trips_2024.shape[0]:,}")
print(f"\nКолонки:")
print(trips_2024.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Загрузить данные за 2024 год
# ----> 2 trips_2024 = load_raw_data(year=2024)
#       4 print(f"Поездок за 2024: {trips_2024.shape[0]:,}")
#       5 print(f"\nКолонки:")
#
# File ~/Desktop/divvy-bikes-analysis/notebooks/../src/data/load_data.py:250, in load_raw_data(year, month)
#     239 """
#     240 Загрузка сырых данных за указанный период.
#     241
#    (...)    247     DataFrame с данными поездок
#     248 """
#     249 loader = DataLoader()
# --> 250 return loader.load_raw_trips_year(year)
#
# File ~/Desktop/divvy-bikes-analysis/notebooks/../src/data/load_data.py:41, in DataLoader.load_raw_trips_year(self, year)
#      38 trip_files = list(year_dir.glob('Divvy_Trips_*.csv'))
#      40 if not trip_files:
# ---> 41     raise FileNotFoundError(f"Не найдены файлы поездок за {year} год")
#      43 # Загружаем и объединяем все файлы
#      44 dfs = []
#
# FileNotFoundError: Не найдены файлы поездок за 2024 год

# %% [markdown]
# ## 3. Использование DataLoader для гибкой загрузки

# %%
loader = DataLoader()

# Загрузить данные за диапазон лет
trips_range = loader.load_raw_trips_range(2020, 2024)

print(f"Поездок за 2020-2024: {trips_range.shape[0]:,}")

# Посмотреть распределение по годам
trips_range.group_by('year').agg(
    pl.count().alias('trips_count')
).sort('year')
# Out:
# Пропуск 2021 года: данные не найдены
# Пропуск 2022 года: данные не найдены
# Пропуск 2023 года: данные не найдены
# Пропуск 2024 года: данные не найдены
# Поездок за 2020-2024: 426,887
# /var/folders/m_/0vg5klms5wqfl8z1jkpk95tr0000gn/T/ipykernel_2759/3276194592.py:10: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   pl.count().alias('trips_count')
# shape: (1, 2)
# ┌──────┬─────────────┐
# │ year ┆ trips_count │
# │ ---  ┆ ---         │
# │ i32  ┆ u32         │
# ╞══════╪═════════════╡
# │ 2020 ┆ 426887      │
# └──────┴─────────────┘

# %% [markdown]
# ## 4. Загрузка промежуточных данных

# %%
# Загрузить очищенные данные
try:
    cleaned_trips = loader.load_interim_data('trips_cleaned')
    print(f"Очищенных поездок: {cleaned_trips.shape[0]:,}")
except FileNotFoundError:
    print("Очищенные данные еще не созданы")
# Out:
# Очищенные данные еще не созданы

# %% [markdown]
# ## 5. Загрузка обработанных данных

# %%
# Загрузить ежедневные агрегаты
try:
    daily_df = load_daily_metrics()
    print(f"Дней с данными: {daily_df.shape[0]:,}")
    daily_df.head()
except FileNotFoundError:
    print("Ежедневные агрегаты еще не созданы")
# Out:
# Ежедневные агрегаты еще не созданы

# %% [markdown]
# ## 6. Сохранение результатов

# %%
# Пример обработки и сохранения
from src.config.paths import INTERIM_DATA_DIR

# Простая обработка
processed = trips_2024.head(1000)  # Пример

# Сохранить результат
loader.save_dataframe(
    processed,
    INTERIM_DATA_DIR / 'example_processed.parquet'
)

print("✓ Данные сохранены")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 from src.config.paths import INTERIM_DATA_DIR
#       4 # Простая обработка
# ----> 5 processed = trips_2024.head(1000)  # Пример
#       7 # Сохранить результат
#       8 loader.save_dataframe(
#       9     processed,
#      10     INTERIM_DATA_DIR / 'example_processed.parquet'
#      11 )
#
# NameError: name 'trips_2024' is not defined

# %% [markdown]
# ## 7. Использование LazyFrame для эффективности

# %%
# Для больших данных используйте LazyFrame
from src.config.paths import TRIPS_FINAL

if TRIPS_FINAL.exists():
    # Ленивая загрузка
    lazy_df = pl.scan_parquet(TRIPS_FINAL)
    
    # Выполнить операции без загрузки всех данных в память
    result = (
        lazy_df
        .filter(pl.col('year') == 2024)
        .group_by('month')
        .agg(pl.count().alias('trips'))
        .collect()  # Только здесь происходит вычисление
    )
    
    print(result)
else:
    print("Финальные данные еще не созданы")
# Out:
# Финальные данные еще не созданы
