# %% [markdown]
# # Профилирование данных Divvy Bikes
#
# Этот notebook демонстрирует использование DataProfiler для анализа данных.

# %%
# Автоперезагрузка модулей
# %load_ext autoreload
# %autoreload 2

# %%
# Настройка путей
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

print(f"Корень проекта: {project_root}")
# Out:
# Корень проекта: /Users/vsevolod/Desktop/divvy-bikes-analysis

# %%
# Импорты
import polars as pl
from src.data.load_data import load_raw_data
from src.data.data_profiler import check_data, quick_check, DataProfiler

print("Импорты успешны")
# Out:
# Импорты успешны

# %% [markdown]
# ## 1. Загрузка данных

# %%
# Загружаем данные за январь 2024
print("Загрузка данных...")
trips = load_raw_data(year=2024, month=1)
print(f"Загружено: {trips.shape[0]:,} поездок")
# Out:
# Загрузка данных...
# Загружено: 144,873 поездок

# %% [markdown]
# ## 2. Полный анализ данных

# %%
# Полный отчет
check_data(trips)
# Out:
# ╔══════════════════════════════════════════════════════════╗
# ║               DATA PROFILING REPORT                      ║
# ╚══════════════════════════════════════════════════════════╝
#
#
# ============================================================
#   БАЗОВАЯ ИНФОРМАЦИЯ
# ============================================================
#
# Размер датасета:
#   Строк: 144,873
#   Колонок: 13
#   Размер в памяти: 19.07 MB
#
# Типы данных:
#   Datetime(time_unit='us', time_zone=None): 2 колонок
#   Float64: 4 колонок
#   String: 7 колонок
#
# Колонки:
#    1. ride_id                        (String)
#    2. rideable_type                  (String)
#    3. started_at                     (Datetime(time_unit='us', time_zone=None))
#    4. ended_at                       (Datetime(time_unit='us', time_zone=None))
#    5. start_station_name             (String)
#    6. start_station_id               (String)
#    7. end_station_name               (String)
#    8. end_station_id                 (String)
#    9. start_lat                      (Float64)
#   10. start_lng                      (Float64)
#   11. end_lat                        (Float64)
#   12. end_lng                        (Float64)
#   13. member_casual                  (String)
#
# ============================================================
#   АНАЛИЗ ПРОПУСКОВ
# ============================================================
#
# Общая статистика:
#   Всего пропусков: 80,404
#   Доля пропусков: 4.27%
#   Строк с пропусками: 31,065 (21.44%)
#
# Пропуски по колонкам:
#   • start_station_name            :   19,165 (13.23%)
#   • start_station_id              :   19,165 (13.23%)
#   • end_station_name              :   20,749 (14.32%)
#   • end_station_id                :   20,749 (14.32%)
#   • end_lat                       :      288 ( 0.20%)
#   • end_lng                       :      288 ( 0.20%)
#
# ============================================================
#   ПРОВЕРКА ДУБЛИКАТОВ
# ============================================================
#
# Полные дубликаты:
#   Полных дубликатов не найдено
#
# Уникальность:
#   Уникальных строк: 144,873
#   Доля уникальных: 100.00%
#
# ============================================================
#   ЧИСЛОВЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 4 числовых колонок
#
# shape: (9, 5)
# ┌────────────┬───────────┬────────────┬───────────┬────────────┐
# │ statistic  ┆ start_lat ┆ start_lng  ┆ end_lat   ┆ end_lng    │
# │ ---        ┆ ---       ┆ ---        ┆ ---       ┆ ---        │
# │ str        ┆ f64       ┆ f64        ┆ f64       ┆ f64        │
# ╞════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │ count      ┆ 144873.0  ┆ 144873.0   ┆ 144585.0  ┆ 144585.0   │
# │ null_count ┆ 0.0       ┆ 0.0        ┆ 288.0     ┆ 288.0      │
# │ mean       ┆ 41.897591 ┆ -87.646706 ┆ 41.897755 ┆ -87.646784 │
# │ std        ┆ 0.048839  ┆ 0.027527   ┆ 0.048893  ┆ 0.027542   │
# │ min        ┆ 41.648588 ┆ -87.844084 ┆ 41.63     ┆ -87.86     │
# │ 25%        ┆ 41.879255 ┆ -87.660294 ┆ 41.879255 ┆ -87.660285 │
# │ 50%        ┆ 41.894345 ┆ -87.64346  ┆ 41.894345 ┆ -87.643353 │
# │ 75%        ┆ 41.925858 ┆ -87.63     ┆ 41.92669  ┆ -87.63     │
# │ max        ┆ 42.07     ┆ -87.528431 ┆ 42.07     ┆ -87.46     │
# └────────────┴───────────┴────────────┴───────────┴────────────┘
#
# ============================================================
#   КАТЕГОРИАЛЬНЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 7 категориальных колонок
#
# ▸ ride_id
#   Уникальных значений: 144,873
#   Пропусков: 0
#   Топ-5 значений:
#     - F61472554D0AC626                        :        1 ( 0.00%)
#     - EBCD89945F4E8A6E                        :        1 ( 0.00%)
#     - F741685A7951B0A5                        :        1 ( 0.00%)
#     - DCE88420BC1DB877                        :        1 ( 0.00%)
#     - 8768C17F99E0730A                        :        1 ( 0.00%)
#
# ▸ rideable_type
#   Уникальных значений: 2
#   Пропусков: 0
#   Топ-5 значений:
#     - classic_bike                            :   76,525 (52.82%)
#     - electric_bike                           :   68,348 (47.18%)
#
# ▸ start_station_name
#   Уникальных значений: 1,000
#   Пропусков: 19,165
#   Топ-5 значений:
#     - None                                    :   19,165 (13.23%)
#     - Clinton St & Washington Blvd            :    1,517 ( 1.05%)
#     - Kingsbury St & Kinzie St                :    1,458 ( 1.01%)
#     - University Ave & 57th St                :    1,361 ( 0.94%)
#     - Clinton St & Madison St                 :    1,323 ( 0.91%)
#
# ▸ start_station_id
#   Уникальных значений: 989
#   Пропусков: 19,165
#   Топ-5 значений:
#     - None                                    :   19,165 (13.23%)
#     - WL-012                                  :    1,517 ( 1.05%)
#     - KA1503000043                            :    1,458 ( 1.01%)
#     - KA1503000071                            :    1,361 ( 0.94%)
#     - TA1305000032                            :    1,323 ( 0.91%)
#
# ▸ end_station_name
#   Уникальных значений: 997
#   Пропусков: 20,749
#   Топ-5 значений:
#     - None                                    :   20,749 (14.32%)
#     - Clinton St & Washington Blvd            :    1,639 ( 1.13%)
#     - Clinton St & Madison St                 :    1,452 ( 1.00%)
#     - Kingsbury St & Kinzie St                :    1,450 ( 1.00%)
#     - University Ave & 57th St                :    1,354 ( 0.93%)
#
# ▸ end_station_id
#   Уникальных значений: 987
#   Пропусков: 20,749
#   Топ-5 значений:
#     - None                                    :   20,749 (14.32%)
#     - WL-012                                  :    1,639 ( 1.13%)
#     - TA1305000032                            :    1,452 ( 1.00%)
#     - KA1503000043                            :    1,450 ( 1.00%)
#     - KA1503000071                            :    1,354 ( 0.93%)
#
# ▸ member_casual
#   Уникальных значений: 2
#   Пропусков: 0
#   Топ-5 значений:
#     - member                                  :  120,413 (83.12%)
#     - casual                                  :   24,460 (16.88%)
#
#
# ============================================================
#   ВРЕМЕННЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 2 временных колонок
#
# ▸ started_at
#   Минимум: 2024-01-01 00:00:39
#   Максимум: 2024-01-31 23:59:40
#   Диапазон: 30 дней
#   Пропусков: 0
#
# ▸ ended_at
#   Минимум: 2024-01-01 00:04:20
#   Максимум: 2024-02-02 00:01:21
#   Диапазон: 31 дней
#   Пропусков: 0
#
#
# ============================================================
#   ПРИМЕРЫ ДАННЫХ
# ============================================================
#
# Первые 3 строк:
# shape: (3, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ride_id   ┆ rideable_ ┆ started_a ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat   ┆ end_lng   ┆ member_c │
# │ ---       ┆ type      ┆ t         ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ asual    │
# │ str       ┆ ---       ┆ ---       ┆ datetime[ ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆ str       ┆ datetime[ ┆ μs]       ┆   ┆           ┆           ┆           ┆ str      │
# │           ┆           ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ C1D650626 ┆ electric_ ┆ 2024-01-1 ┆ 2024-01-1 ┆ … ┆ -87.63473 ┆ 41.889177 ┆ -87.63850 ┆ member   │
# │ C8C899A   ┆ bike      ┆ 2         ┆ 2         ┆   ┆ 7         ┆           ┆ 6         ┆          │
# │           ┆           ┆ 15:30:27  ┆ 15:37:59  ┆   ┆           ┆           ┆           ┆          │
# │ EECD38BDB ┆ electric_ ┆ 2024-01-0 ┆ 2024-01-0 ┆ … ┆ -87.63444 ┆ 41.889177 ┆ -87.63850 ┆ member   │
# │ 25BFCB0   ┆ bike      ┆ 8         ┆ 8         ┆   ┆           ┆           ┆ 6         ┆          │
# │           ┆           ┆ 15:45:46  ┆ 15:52:59  ┆   ┆           ┆           ┆           ┆          │
# │ F4A9CE780 ┆ electric_ ┆ 2024-01-2 ┆ 2024-01-2 ┆ … ┆ -87.63447 ┆ 41.889177 ┆ -87.63850 ┆ member   │
# │ 61F17F7   ┆ bike      ┆ 7         ┆ 7         ┆   ┆           ┆           ┆ 6         ┆          │
# │           ┆           ┆ 12:27:19  ┆ 12:35:19  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# Последние 3 строк:
# shape: (3, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ride_id   ┆ rideable_ ┆ started_a ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat   ┆ end_lng   ┆ member_c │
# │ ---       ┆ type      ┆ t         ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ asual    │
# │ str       ┆ ---       ┆ ---       ┆ datetime[ ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆ str       ┆ datetime[ ┆ μs]       ┆   ┆           ┆           ┆           ┆ str      │
# │           ┆           ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 147C5EE92 ┆ classic_b ┆ 2024-01-0 ┆ 2024-01-0 ┆ … ┆ -87.62191 ┆ 41.882134 ┆ -87.62512 ┆ member   │
# │ 7C05355   ┆ ike       ┆ 3         ┆ 3         ┆   ┆ 5         ┆           ┆ 5         ┆          │
# │           ┆           ┆ 09:03:19  ┆ 09:13:28  ┆   ┆           ┆           ┆           ┆          │
# │ D91482EE5 ┆ classic_b ┆ 2024-01-3 ┆ 2024-01-3 ┆ … ┆ -87.6687  ┆ 41.965221 ┆ -87.65813 ┆ member   │
# │ 88191FC   ┆ ike       ┆ 0         ┆ 0         ┆   ┆           ┆           ┆ 9         ┆          │
# │           ┆           ┆ 16:20:19  ┆ 16:30:11  ┆   ┆           ┆           ┆           ┆          │
# │ DE13FAC41 ┆ classic_b ┆ 2024-01-0 ┆ 2024-01-0 ┆ … ┆ -87.62191 ┆ 41.882134 ┆ -87.62512 ┆ member   │
# │ 6BD3B33   ┆ ike       ┆ 5         ┆ 5         ┆   ┆ 5         ┆           ┆ 5         ┆          │
# │           ┆           ┆ 16:43:53  ┆ 17:04:48  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# Случайная выборка (3 строк):
# shape: (3, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ride_id   ┆ rideable_ ┆ started_a ┆ ended_at  ┆ … ┆ start_lng ┆ end_lat   ┆ end_lng   ┆ member_c │
# │ ---       ┆ type      ┆ t         ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ asual    │
# │ str       ┆ ---       ┆ ---       ┆ datetime[ ┆   ┆ f64       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆ str       ┆ datetime[ ┆ μs]       ┆   ┆           ┆           ┆           ┆ str      │
# │           ┆           ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8FF5A678A ┆ classic_b ┆ 2024-01-2 ┆ 2024-01-2 ┆ … ┆ -87.64907 ┆ 41.949074 ┆ -87.64863 ┆ member   │
# │ 9073FCA   ┆ ike       ┆ 1         ┆ 1         ┆   ┆ 7         ┆           ┆ 6         ┆          │
# │           ┆           ┆ 14:59:12  ┆ 15:40:01  ┆   ┆           ┆           ┆           ┆          │
# │ 2187BF95A ┆ classic_b ┆ 2024-01-0 ┆ 2024-01-0 ┆ … ┆ -87.64808 ┆ 41.890173 ┆ -87.62618 ┆ member   │
# │ B1A0AF3   ┆ ike       ┆ 5         ┆ 5         ┆   ┆ 9         ┆           ┆ 5         ┆          │
# │           ┆           ┆ 18:45:12  ┆ 18:58:32  ┆   ┆           ┆           ┆           ┆          │
# │ 5A80C1084 ┆ classic_b ┆ 2024-01-0 ┆ 2024-01-0 ┆ … ┆ -87.68201 ┆ 41.91552  ┆ -87.68702 ┆ member   │
# │ 794D4DC   ┆ ike       ┆ 3         ┆ 3         ┆   ┆ 7         ┆           ┆ 2         ┆          │
# │           ┆           ┆ 08:10:41  ┆ 08:20:28  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
#
# Анализ завершен!

# %% [markdown]
# ## 3. Быстрая проверка (без примеров)

# %%
# Быстрая проверка
quick_check(trips)
# Out:
# ============================================================
#   БАЗОВАЯ ИНФОРМАЦИЯ
# ============================================================
#
# Размер датасета:
#   Строк: 144,873
#   Колонок: 13
#   Размер в памяти: 19.07 MB
#
# Типы данных:
#   Datetime(time_unit='us', time_zone=None): 2 колонок
#   Float64: 4 колонок
#   String: 7 колонок
#
# Колонки:
#    1. ride_id                        (String)
#    2. rideable_type                  (String)
#    3. started_at                     (Datetime(time_unit='us', time_zone=None))
#    4. ended_at                       (Datetime(time_unit='us', time_zone=None))
#    5. start_station_name             (String)
#    6. start_station_id               (String)
#    7. end_station_name               (String)
#    8. end_station_id                 (String)
#    9. start_lat                      (Float64)
#   10. start_lng                      (Float64)
#   11. end_lat                        (Float64)
#   12. end_lng                        (Float64)
#   13. member_casual                  (String)
#
# ============================================================
#   АНАЛИЗ ПРОПУСКОВ
# ============================================================
#
# Общая статистика:
#   Всего пропусков: 80,404
#   Доля пропусков: 4.27%
#   Строк с пропусками: 31,065 (21.44%)
#
# Пропуски по колонкам:
#   • start_station_name            :   19,165 (13.23%)
#   • start_station_id              :   19,165 (13.23%)
#   • end_station_name              :   20,749 (14.32%)
#   • end_station_id                :   20,749 (14.32%)
#   • end_lat                       :      288 ( 0.20%)
#   • end_lng                       :      288 ( 0.20%)
#
# ============================================================
#   ПРОВЕРКА ДУБЛИКАТОВ
# ============================================================
#
# Полные дубликаты:
#   Полных дубликатов не найдено
#
# Уникальность:
#   Уникальных строк: 144,873
#   Доля уникальных: 100.00%

# %% [markdown]
# ## 4. Использование DataProfiler напрямую

# %%
# Создаем профайлер
profiler = DataProfiler(trips)

# Можем вызывать методы по отдельности
profiler.basic_info()
# Out:
# ============================================================
#   БАЗОВАЯ ИНФОРМАЦИЯ
# ============================================================
#
# Размер датасета:
#   Строк: 144,873
#   Колонок: 13
#   Размер в памяти: 19.07 MB
#
# Типы данных:
#   Datetime(time_unit='us', time_zone=None): 2 колонок
#   Float64: 4 колонок
#   String: 7 колонок
#
# Колонки:
#    1. ride_id                        (String)
#    2. rideable_type                  (String)
#    3. started_at                     (Datetime(time_unit='us', time_zone=None))
#    4. ended_at                       (Datetime(time_unit='us', time_zone=None))
#    5. start_station_name             (String)
#    6. start_station_id               (String)
#    7. end_station_name               (String)
#    8. end_station_id                 (String)
#    9. start_lat                      (Float64)
#   10. start_lng                      (Float64)
#   11. end_lat                        (Float64)
#   12. end_lng                        (Float64)
#   13. member_casual                  (String)

# %%
# Только проверка пропусков
profiler.check_missing()
# Out:
# ============================================================
#   АНАЛИЗ ПРОПУСКОВ
# ============================================================
#
# Общая статистика:
#   Всего пропусков: 80,404
#   Доля пропусков: 4.27%
#   Строк с пропусками: 31,065 (21.44%)
#
# Пропуски по колонкам:
#   • start_station_name            :   19,165 (13.23%)
#   • start_station_id              :   19,165 (13.23%)
#   • end_station_name              :   20,749 (14.32%)
#   • end_station_id                :   20,749 (14.32%)
#   • end_lat                       :      288 ( 0.20%)
#   • end_lng                       :      288 ( 0.20%)

# %%
# Только категориальные данные
profiler.describe_categorical()
# Out:
# ============================================================
#   КАТЕГОРИАЛЬНЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 7 категориальных колонок
#
# ▸ ride_id
#   Уникальных значений: 144,873
#   Пропусков: 0
#   Топ-5 значений:
#     - F33E699278223B87                        :        1 ( 0.00%)
#     - AC2F69CD8F50DB69                        :        1 ( 0.00%)
#     - 0BA3D3A4C7DFA930                        :        1 ( 0.00%)
#     - 2AFD3854E78879ED                        :        1 ( 0.00%)
#     - 6032CBB6F395019A                        :        1 ( 0.00%)
#
# ▸ rideable_type
#   Уникальных значений: 2
#   Пропусков: 0
#   Топ-5 значений:
#     - classic_bike                            :   76,525 (52.82%)
#     - electric_bike                           :   68,348 (47.18%)
#
# ▸ start_station_name
#   Уникальных значений: 1,000
#   Пропусков: 19,165
#   Топ-5 значений:
#     - None                                    :   19,165 (13.23%)
#     - Clinton St & Washington Blvd            :    1,517 ( 1.05%)
#     - Kingsbury St & Kinzie St                :    1,458 ( 1.01%)
#     - University Ave & 57th St                :    1,361 ( 0.94%)
#     - Clinton St & Madison St                 :    1,323 ( 0.91%)
#
# ▸ start_station_id
#   Уникальных значений: 989
#   Пропусков: 19,165
#   Топ-5 значений:
#     - None                                    :   19,165 (13.23%)
#     - WL-012                                  :    1,517 ( 1.05%)
#     - KA1503000043                            :    1,458 ( 1.01%)
#     - KA1503000071                            :    1,361 ( 0.94%)
#     - TA1305000032                            :    1,323 ( 0.91%)
#
# ▸ end_station_name
#   Уникальных значений: 997
#   Пропусков: 20,749
#   Топ-5 значений:
#     - None                                    :   20,749 (14.32%)
#     - Clinton St & Washington Blvd            :    1,639 ( 1.13%)
#     - Clinton St & Madison St                 :    1,452 ( 1.00%)
#     - Kingsbury St & Kinzie St                :    1,450 ( 1.00%)
#     - University Ave & 57th St                :    1,354 ( 0.93%)
#
# ▸ end_station_id
#   Уникальных значений: 987
#   Пропусков: 20,749
#   Топ-5 значений:
#     - None                                    :   20,749 (14.32%)
#     - WL-012                                  :    1,639 ( 1.13%)
#     - TA1305000032                            :    1,452 ( 1.00%)
#     - KA1503000043                            :    1,450 ( 1.00%)
#     - KA1503000071                            :    1,354 ( 0.93%)
#
# ▸ member_casual
#   Уникальных значений: 2
#   Пропусков: 0
#   Топ-5 значений:
#     - member                                  :  120,413 (83.12%)
#     - casual                                  :   24,460 (16.88%)

# %%
# Только временные данные
profiler.describe_datetime()
# Out:
# ============================================================
#   ВРЕМЕННЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 2 временных колонок
#
# ▸ started_at
#   Минимум: 2024-01-01 00:00:39
#   Максимум: 2024-01-31 23:59:40
#   Диапазон: 30 дней
#   Пропусков: 0
#
# ▸ ended_at
#   Минимум: 2024-01-01 00:04:20
#   Максимум: 2024-02-02 00:01:21
#   Диапазон: 31 дней
#   Пропусков: 0

# %% [markdown]
# ## 5. Сравнение разных месяцев

# %%
# Сравним январь и июль
print("=" * 60)
print("ЯНВАРЬ 2024")
print("=" * 60)
trips_jan = load_raw_data(year=2024, month=1)
quick_check(trips_jan)

print("\n" + "=" * 60)
print("ИЮЛЬ 2024")
print("=" * 60)
trips_jul = load_raw_data(year=2024, month=7)
quick_check(trips_jul)
# Out:
# ============================================================
# ЯНВАРЬ 2024
# ============================================================
#
# ============================================================
#   БАЗОВАЯ ИНФОРМАЦИЯ
# ============================================================
#
# Размер датасета:
#   Строк: 144,873
#   Колонок: 13
#   Размер в памяти: 19.07 MB
#
# Типы данных:
#   Datetime(time_unit='us', time_zone=None): 2 колонок
#   Float64: 4 колонок
#   String: 7 колонок
#
# Колонки:
#    1. ride_id                        (String)
#    2. rideable_type                  (String)
#    3. started_at                     (Datetime(time_unit='us', time_zone=None))
#    4. ended_at                       (Datetime(time_unit='us', time_zone=None))
#    5. start_station_name             (String)
#    6. start_station_id               (String)
#    7. end_station_name               (String)
#    8. end_station_id                 (String)
#    9. start_lat                      (Float64)
#   10. start_lng                      (Float64)
#   11. end_lat                        (Float64)
#   12. end_lng                        (Float64)
#   13. member_casual                  (String)
#
# ============================================================
#   АНАЛИЗ ПРОПУСКОВ
# ============================================================
#
# Общая статистика:
#   Всего пропусков: 80,404
#   Доля пропусков: 4.27%
#   Строк с пропусками: 31,065 (21.44%)
#
# Пропуски по колонкам:
#   • start_station_name            :   19,165 (13.23%)
#   • start_station_id              :   19,165 (13.23%)
#   • end_station_name              :   20,749 (14.32%)
#   • end_station_id                :   20,749 (14.32%)
#   • end_lat                       :      288 ( 0.20%)
#   • end_lng                       :      288 ( 0.20%)
#
# ============================================================
#   ПРОВЕРКА ДУБЛИКАТОВ
# ============================================================
#
# Полные дубликаты:
#   Полных дубликатов не найдено
#
# Уникальность:
#   Уникальных строк: 144,873
#   Доля уникальных: 100.00%
#
# ============================================================
# ИЮЛЬ 2024
# ============================================================
#
# ============================================================
#   БАЗОВАЯ ИНФОРМАЦИЯ
# ============================================================
#
# Размер датасета:
#   Строк: 748,962
#   Колонок: 13
#   Размер в памяти: 96.40 MB
#
# Типы данных:
#   Datetime(time_unit='us', time_zone=None): 2 колонок
#   Float64: 4 колонок
#   String: 7 колонок
#
# Колонки:
#    1. ride_id                        (String)
#    2. rideable_type                  (String)
#    3. started_at                     (Datetime(time_unit='us', time_zone=None))
#    4. ended_at                       (Datetime(time_unit='us', time_zone=None))
#    5. start_station_name             (String)
#    6. start_station_id               (String)
#    7. end_station_name               (String)
#    8. end_station_id                 (String)
#    9. start_lat                      (Float64)
#   10. start_lng                      (Float64)
#   11. end_lat                        (Float64)
#   12. end_lng                        (Float64)
#   13. member_casual                  (String)
#
# ============================================================
#   АНАЛИЗ ПРОПУСКОВ
# ============================================================
#
# Общая статистика:
#   Всего пропусков: 554,560
#   Доля пропусков: 5.70%
#   Строк с пропусками: 208,031 (27.78%)
#
# Пропуски по колонкам:
#   • start_station_name            :  136,965 (18.29%)
#   • start_station_id              :  136,965 (18.29%)
#   • end_station_name              :  139,224 (18.59%)
#   • end_station_id                :  139,224 (18.59%)
#   • end_lat                       :    1,091 ( 0.15%)
#   • end_lng                       :    1,091 ( 0.15%)
#
# ============================================================
#   ПРОВЕРКА ДУБЛИКАТОВ
# ============================================================
#
# Полные дубликаты:
#   Полных дубликатов не найдено
#
# Уникальность:
#   Уникальных строк: 748,962
#   Доля уникальных: 100.00%

# %% [markdown]
# ## 6. Анализ после фильтрации

# %%
# Фильтруем данные
trips_filtered = trips.filter(
    pl.col('start_station_name').is_not_null() &
    pl.col('end_station_name').is_not_null()
)

print(f"До фильтрации: {trips.shape[0]:,} поездок")
print(f"После фильтрации: {trips_filtered.shape[0]:,} поездок")
print(f"Удалено: {trips.shape[0] - trips_filtered.shape[0]:,} поездок\n")

# Анализ отфильтрованных данных
check_data(trips_filtered, show_samples=False)
# Out:
# До фильтрации: 144,873 поездок
# После фильтрации: 113,808 поездок
# Удалено: 31,065 поездок
#
#
#
# ╔══════════════════════════════════════════════════════════╗
# ║               DATA PROFILING REPORT                      ║
# ╚══════════════════════════════════════════════════════════╝
#
#
# ============================================================
#   БАЗОВАЯ ИНФОРМАЦИЯ
# ============================================================
#
# Размер датасета:
#   Строк: 113,808
#   Колонок: 13
#   Размер в памяти: 15.92 MB
#
# Типы данных:
#   Datetime(time_unit='us', time_zone=None): 2 колонок
#   Float64: 4 колонок
#   String: 7 колонок
#
# Колонки:
#    1. ride_id                        (String)
#    2. rideable_type                  (String)
#    3. started_at                     (Datetime(time_unit='us', time_zone=None))
#    4. ended_at                       (Datetime(time_unit='us', time_zone=None))
#    5. start_station_name             (String)
#    6. start_station_id               (String)
#    7. end_station_name               (String)
#    8. end_station_id                 (String)
#    9. start_lat                      (Float64)
#   10. start_lng                      (Float64)
#   11. end_lat                        (Float64)
#   12. end_lng                        (Float64)
#   13. member_casual                  (String)
#
# ============================================================
#   АНАЛИЗ ПРОПУСКОВ
# ============================================================
#
# Общая статистика:
#   Всего пропусков: 0
#   Доля пропусков: 0.00%
#   Строк с пропусками: 0 (0.00%)
#
# Пропуски по колонкам:
#   Пропусков не обнаружено!
#
# ============================================================
#   ПРОВЕРКА ДУБЛИКАТОВ
# ============================================================
#
# Полные дубликаты:
#   Полных дубликатов не найдено
#
# Уникальность:
#   Уникальных строк: 113,808
#   Доля уникальных: 100.00%
#
# ============================================================
#   ЧИСЛОВЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 4 числовых колонок
#
# shape: (9, 5)
# ┌────────────┬───────────┬────────────┬───────────┬────────────┐
# │ statistic  ┆ start_lat ┆ start_lng  ┆ end_lat   ┆ end_lng    │
# │ ---        ┆ ---       ┆ ---        ┆ ---       ┆ ---        │
# │ str        ┆ f64       ┆ f64        ┆ f64       ┆ f64        │
# ╞════════════╪═══════════╪════════════╪═══════════╪════════════╡
# │ count      ┆ 113808.0  ┆ 113808.0   ┆ 113808.0  ┆ 113808.0   │
# │ null_count ┆ 0.0       ┆ 0.0        ┆ 0.0       ┆ 0.0        │
# │ mean       ┆ 41.895256 ┆ -87.644673 ┆ 41.895486 ┆ -87.644738 │
# │ std        ┆ 0.046928  ┆ 0.02573    ┆ 0.047028  ┆ 0.025659   │
# │ min        ┆ 41.648588 ┆ -87.844043 ┆ 41.653444 ┆ -87.841098 │
# │ 25%        ┆ 41.878166 ┆ -87.658393 ┆ 41.878166 ┆ -87.658416 │
# │ 50%        ┆ 41.891847 ┆ -87.641697 ┆ 41.892048 ┆ -87.641697 │
# │ 75%        ┆ 41.92154  ┆ -87.629572 ┆ 41.921822 ┆ -87.629634 │
# │ max        ┆ 42.064854 ┆ -87.528431 ┆ 42.064854 ┆ -87.528232 │
# └────────────┴───────────┴────────────┴───────────┴────────────┘
#
# ============================================================
#   КАТЕГОРИАЛЬНЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 7 категориальных колонок
#
# ▸ ride_id
#   Уникальных значений: 113,808
#   Пропусков: 0
#   Топ-5 значений:
#     - 2A342BD17E2836DF                        :        1 ( 0.00%)
#     - 573D696A7AE8065E                        :        1 ( 0.00%)
#     - F87BF533AFB9E41A                        :        1 ( 0.00%)
#     - DD19EDBC85DA6EA1                        :        1 ( 0.00%)
#     - 8D5BEF6121E96F0D                        :        1 ( 0.00%)
#
# ▸ rideable_type
#   Уникальных значений: 2
#   Пропусков: 0
#   Топ-5 значений:
#     - classic_bike                            :   76,209 (66.96%)
#     - electric_bike                           :   37,599 (33.04%)
#
# ▸ start_station_name
#   Уникальных значений: 937
#   Пропусков: 0
#   Топ-5 значений:
#     - Clinton St & Washington Blvd            :    1,391 ( 1.22%)
#     - Kingsbury St & Kinzie St                :    1,368 ( 1.20%)
#     - University Ave & 57th St                :    1,267 ( 1.11%)
#     - Clinton St & Madison St                 :    1,223 ( 1.07%)
#     - Ellis Ave & 60th St                     :    1,155 ( 1.01%)
#
# ▸ start_station_id
#   Уникальных значений: 933
#   Пропусков: 0
#   Топ-5 значений:
#     - WL-012                                  :    1,391 ( 1.22%)
#     - KA1503000043                            :    1,368 ( 1.20%)
#     - KA1503000071                            :    1,267 ( 1.11%)
#     - TA1305000032                            :    1,223 ( 1.07%)
#     - KA1503000014                            :    1,155 ( 1.01%)
#
# ▸ end_station_name
#   Уникальных значений: 946
#   Пропусков: 0
#   Топ-5 значений:
#     - Clinton St & Washington Blvd            :    1,537 ( 1.35%)
#     - Clinton St & Madison St                 :    1,365 ( 1.20%)
#     - Kingsbury St & Kinzie St                :    1,357 ( 1.19%)
#     - University Ave & 57th St                :    1,278 ( 1.12%)
#     - Ellis Ave & 60th St                     :    1,168 ( 1.03%)
#
# ▸ end_station_id
#   Уникальных значений: 939
#   Пропусков: 0
#   Топ-5 значений:
#     - WL-012                                  :    1,537 ( 1.35%)
#     - TA1305000032                            :    1,365 ( 1.20%)
#     - KA1503000043                            :    1,357 ( 1.19%)
#     - KA1503000071                            :    1,278 ( 1.12%)
#     - KA1503000014                            :    1,168 ( 1.03%)
#
# ▸ member_casual
#   Уникальных значений: 2
#   Пропусков: 0
#   Топ-5 значений:
#     - member                                  :   96,095 (84.44%)
#     - casual                                  :   17,713 (15.56%)
#
#
# ============================================================
#   ВРЕМЕННЫЕ ДАННЫЕ
# ============================================================
#
# Найдено 2 временных колонок
#
# ▸ started_at
#   Минимум: 2024-01-01 00:01:01
#   Максимум: 2024-01-31 23:59:20
#   Диапазон: 30 дней
#   Пропусков: 0
#
# ▸ ended_at
#   Минимум: 2024-01-01 00:07:01
#   Максимум: 2024-02-01 21:44:01
#   Диапазон: 31 дней
#   Пропусков: 0
#
#
# Анализ завершен!
