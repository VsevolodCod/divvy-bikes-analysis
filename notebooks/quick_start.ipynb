# %% [markdown]
# # Быстрый старт - Загрузка данных Divvy Bikes
#
# Этот notebook показывает как быстро начать работу с данными.

# %%
# Добавляем корень проекта в путь
import sys
from pathlib import Path

# Находим корень проекта (на уровень выше notebooks/)
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

print(f"Корень проекта: {project_root}")
# Out:
# Корень проекта: /Users/vsevolod/Desktop/divvy-bikes-analysis

# %%
# Импортируем необходимые библиотеки
import polars as pl
from src.data.load_data import load_raw_data, DataLoader

print("Импорты успешны")
# Out:
# Импорты успешны

# %%
   from src.data.load_data import load_raw_data
   trips = load_raw_data(year=2024)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 from src.data.load_data import load_raw_data
# ----> 2 trips = load_raw_data(year=2024)
#
# File ~/Desktop/divvy-bikes-analysis/src/data/load_data.py:250, in load_raw_data(year, month)
#     239 """
#     240 Загрузка сырых данных за указанный период.
#     241
#    (...)    247     DataFrame с данными поездок
#     248 """
#     249 loader = DataLoader()
# --> 250 return loader.load_raw_trips_year(year)
#
# File ~/Desktop/divvy-bikes-analysis/src/data/load_data.py:41, in DataLoader.load_raw_trips_year(self, year)
#      38 trip_files = list(year_dir.glob('Divvy_Trips_*.csv'))
#      40 if not trip_files:
# ---> 41     raise FileNotFoundError(f"Не найдены файлы поездок за {year} год")
#      43 # Загружаем и объединяем все файлы
#      44 dfs = []
#
# FileNotFoundError: Не найдены файлы поездок за 2024 год

# %% [markdown]
# ## 1. Загрузка данных за один год

# %%
# Загружаем данные за 2024 год
print("Загрузка данных за 2024 год...")
trips_2024 = load_raw_data(year=2024)

print(f"\nЗагружено поездок: {trips_2024.shape[0]:,}")
print(f"Колонок: {trips_2024.shape[1]}")
print(f"\nПервые 5 строк:")
trips_2024.head()
# Out:
# Загрузка данных за 2024 год...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Загружаем данные за 2024 год
#       2 print("Загрузка данных за 2024 год...")
# ----> 3 trips_2024 = load_raw_data(year=2024)
#       5 print(f"\nЗагружено поездок: {trips_2024.shape[0]:,}")
#       6 print(f"Колонок: {trips_2024.shape[1]}")
#
# File ~/Desktop/divvy-bikes-analysis/src/data/load_data.py:250, in load_raw_data(year, month)
#     239 """
#     240 Загрузка сырых данных за указанный период.
#     241
#    (...)    247     DataFrame с данными поездок
#     248 """
#     249 loader = DataLoader()
# --> 250 return loader.load_raw_trips_year(year)
#
# File ~/Desktop/divvy-bikes-analysis/src/data/load_data.py:41, in DataLoader.load_raw_trips_year(self, year)
#      38 trip_files = list(year_dir.glob('Divvy_Trips_*.csv'))
#      40 if not trip_files:
# ---> 41     raise FileNotFoundError(f"Не найдены файлы поездок за {year} год")
#      43 # Загружаем и объединяем все файлы
#      44 dfs = []
#
# FileNotFoundError: Не найдены файлы поездок за 2024 год

# %%
# Посмотрим на колонки
print("Колонки в датасете:")
for col in trips_2024.columns:
    print(f"  - {col}")
# Out:
# Колонки в датасете:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Посмотрим на колонки
#       2 print("Колонки в датасете:")
# ----> 3 for col in trips_2024.columns:
#       4     print(f"  - {col}")
#
# NameError: name 'trips_2024' is not defined

# %% [markdown]
# ## 2. Базовая статистика

# %%
# Описательная статистика
trips_2024.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Описательная статистика
# ----> 2 trips_2024.describe()
#
# NameError: name 'trips_2024' is not defined

# %% [markdown]
# ## 3. Загрузка данных за несколько лет

# %%
# Используем DataLoader для загрузки диапазона лет
loader = DataLoader()

print("Загрузка данных за 2022-2024...")
trips_range = loader.load_raw_trips_range(2022, 2024)

print(f"\nЗагружено поездок: {trips_range.shape[0]:,}")

# Распределение по годам
yearly_stats = trips_range.group_by('year').agg(
    pl.count().alias('total_trips')
).sort('year')

print("\nПоездок по годам:")
yearly_stats
# Out:
# Пропуск 2022 года: данные не найдены
# Пропуск 2023 года: данные не найдены
# Пропуск 2024 года: данные не найдены
# Загрузка данных за 2022-2024...
#
# Загружено поездок: 0
# /var/folders/m_/0vg5klms5wqfl8z1jkpk95tr0000gn/T/ipykernel_3101/2794487638.py:11: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   pl.count().alias('total_trips')
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 10
#       7 print(f"\nЗагружено поездок: {trips_range.shape[0]:,}")
#       9 # Распределение по годам
# ---> 10 yearly_stats = trips_range.group_by('year').agg(
#      11     pl.count().alias('total_trips')
#      12 ).sort('year')
#      14 print("\nПоездок по годам:")
#      15 yearly_stats
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/dataframe/group_by.py:242, in GroupBy.agg(self, *aggs, **named_aggs)
#     136 """
#     137 Compute aggregations for each group of a group by operation.
#     138
#    (...)    234 └─────┴───────┴────────────────┘
#     235 """
#     236 from polars.lazyframe.opt_flags import QueryOptFlags
#     238 return (
#     239     self.df.lazy()
#     240     .group_by(*self.by, **self.named_by, maintain_order=self.maintain_order)
#     241     .agg(*aggs, **named_aggs)
# --> 242     .collect(optimizations=QueryOptFlags.none())
#     243 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/lazyframe/opt_flags.py:328, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     327 kwargs["optimizations"] = optflags
# --> 328 return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/lazyframe/frame.py:2422, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2420 # Only for testing purposes
#    2421 callback = _kwargs.get("post_opt_callback", callback)
# -> 2422 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: unable to find column "year"; valid columns: []
#
# Resolved plan until failure:
#
# 	---> FAILED HERE RESOLVING 'sink' <---
# DF []; PROJECT */0 COLUMNS

# %% [markdown]
# ## 4. Простой анализ

# %%
# Пример анализа: топ-10 популярных станций отправления
# (Название колонки может отличаться в зависимости от года)

# Попробуем найти колонку со станцией отправления
station_cols = [col for col in trips_2024.columns if 'from' in col.lower() or 'start' in col.lower()]
print(f"Найденные колонки станций: {station_cols}")

if station_cols:
    station_col = station_cols[0]
    top_stations = (
        trips_2024
        .group_by(station_col)
        .agg(pl.count().alias('trips'))
        .sort('trips', descending=True)
        .head(10)
    )
    print(f"\nТоп-10 станций отправления:")
    display(top_stations)
else:
    print("Колонка со станцией не найдена")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       1 # Пример анализа: топ-10 популярных станций отправления
#       2 # (Название колонки может отличаться в зависимости от года)
#       3
#       4 # Попробуем найти колонку со станцией отправления
# ----> 5 station_cols = [col for col in trips_2024.columns if 'from' in col.lower() or 'start' in col.lower()]
#       6 print(f"Найденные колонки станций: {station_cols}")
#       8 if station_cols:
#
# NameError: name 'trips_2024' is not defined

# %% [markdown]
# ## 5. Сохранение обработанных данных

# %%
# Пример: сохраним данные за 2024 в Parquet формат
from src.config.paths import INTERIM_DATA_DIR

output_path = INTERIM_DATA_DIR / 'trips_2024_raw.parquet'

loader.save_dataframe(
    trips_2024,
    output_path,
    format='parquet'
)

print(f"Данные сохранены: {output_path}")
print(f"Размер файла: {output_path.stat().st_size / 1024 / 1024:.1f} MB")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 7
#       2 from src.config.paths import INTERIM_DATA_DIR
#       4 output_path = INTERIM_DATA_DIR / 'trips_2024_raw.parquet'
#       6 loader.save_dataframe(
# ----> 7     trips_2024,
#       8     output_path,
#       9     format='parquet'
#      10 )
#      12 print(f"Данные сохранены: {output_path}")
#      13 print(f"Размер файла: {output_path.stat().st_size / 1024 / 1024:.1f} MB")
#
# NameError: name 'trips_2024' is not defined

# %% [markdown]
# ## 6. Проверка сохраненных данных

# %%
# Загрузим обратно для проверки
trips_loaded = pl.read_parquet(output_path)

print(f"Загружено из Parquet: {trips_loaded.shape[0]:,} строк")
print(f"Данные идентичны: {trips_2024.shape == trips_loaded.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Загрузим обратно для проверки
# ----> 2 trips_loaded = pl.read_parquet(output_path)
#       4 print(f"Загружено из Parquet: {trips_loaded.shape[0]:,} строк")
#       5 print(f"Данные идентичны: {trips_2024.shape == trips_loaded.shape}")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     123 @wraps(function)
#     124 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#     125     _rename_keyword_argument(
#     126         old_name, new_name, kwargs, function.__qualname__, version
#     127     )
# --> 128     return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/io/parquet/functions.py:289, in read_parquet(source, columns, n_rows, row_index_name, row_index_offset, parallel, use_statistics, hive_partitioning, glob, schema, hive_schema, try_parse_hive_dates, rechunk, low_memory, storage_options, credential_provider, retries, use_pyarrow, pyarrow_options, memory_map, include_file_paths, missing_columns, allow_missing_columns)
#     286     else:
#     287         lf = lf.select(columns)
# --> 289 return lf.collect()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/lazyframe/opt_flags.py:328, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     327 kwargs["optimizations"] = optflags
# --> 328 return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/polars/lazyframe/frame.py:2422, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2420 # Only for testing purposes
#    2421 callback = _kwargs.get("post_opt_callback", callback)
# -> 2422 return wrap_df(ldf.collect(engine, callback))
#
# FileNotFoundError: No such file or directory (os error 2): /Users/vsevolod/Desktop/divvy-bikes-analysis/data/interim/trips_2024_raw.parquet
#
# This error occurred with the following context stack:
# 	[1] 'parquet scan'
# 	[2] 'sink'
